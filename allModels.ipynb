# %% [markdown]
# Word Frequency Module

# %%
import keras
from keras import layers

CNN_input = keras.Input(shape=(32, 9, 11, 276, 1), batch_size=32, name = 'SentenceInput')

#Conv Block 1
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm1'))(CNN_input)
x = layers.TimeDistributed(layers.Conv3D(16, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv1'))(x)

#Find time attention for each channel
time_dense1 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense1_1'))
time_dense2 = layers.TimeDistributed(layers.Dense(16, activation = 'relu', name = 'TimeDense1_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool1'))(x)
fx_max = time_dense1(fx_max)
fx_max = time_dense2(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool1'))(x)
fx_avg = time_dense1(fx_avg)
fx_avg = time_dense2(fx_avg)

time_attention = layers.Add(name = 'TimeAdd1')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid1')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate1')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool1'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool1'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat1')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,1), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn1'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate1')([space_attention, fx])

#Apply Time and Space attention
block1out = layers.Add(name = 'AttnApply1')([fx, x])

# #Conv Block 2

# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm2'))(block1out)
# x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv2'))(x)

# #Find time attention for each channel
# time_dense3 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense2_1'))
# time_dense4 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense2_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool2'))(x)
# fx_max = time_dense3(fx_max)
# fx_max = time_dense4(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool2'))(x)
# fx_avg = time_dense3(fx_avg)
# fx_avg = time_dense4(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd2')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid2')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate2')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool2'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool2'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat2')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn2'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate2')([space_attention, fx])
# block2out = layers.Add(name = 'TimeSpaceAttnApply2')([fx, x])

# #Conv Block 3
# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm3'))(block2out)
# x = layers.TimeDistributed(layers.Conv3D(64, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv3'))(x)

# time_dense5 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense3_1'))
# time_dense6 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense3_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool3'))(x)
# fx_max = time_dense5(fx_max)
# fx_max = time_dense6(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool3'))(x)
# fx_avg = time_dense5(fx_avg)
# fx_avg = time_dense6(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd3')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid3')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate3')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool3'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SapceAvgPool3'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat3')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv3'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate3')([space_attention, fx])
# block3out = layers.Add(name = 'TimeSpaceAttnApply3')([fx, x])

#Conv Block 4

x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block1out)
x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv4'))(x)

time_dense7 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense4_1'))
time_dense8 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense4_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name='TimeMaxPool4'))(x)
fx_max = time_dense7(fx_max)
fx_max = time_dense8(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool4'))(x)
fx_avg = time_dense7(fx_avg)
fx_avg = time_dense8(fx_avg)

time_attention = layers.Add(name = 'TimeAdd4')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid4')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate4')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool4'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool4'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat4')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv4'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate4')([space_attention, fx])
block4out = layers.Add(name = 'TimeSpaceAttnApply4')([fx, x])

# Final word vector maker
x = layers.TimeDistributed(layers.MaxPool3D(pool_size = (3,3,25), name = 'FinalMaxPool'))(block4out)
x = layers.TimeDistributed(layers.Flatten(name = 'Flatten'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense1'))(x)
x = layers.TimeDistributed(layers.Dense(32, activation='relu', name = 'FinalDense2'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense3'))(x)
x = layers.TimeDistributed(layers.Dense(16, name = 'WordFreqOutput'))(x)
CNN_output = layers.TimeDistributed(layers.Dense(1))(x)

wordfreq_model = keras.Model(CNN_input, CNN_output)
wordfreq_model.summary()

wordfreq_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.MeanSquaredError(),
    metrics=keras.metrics.MeanAbsoluteError()
    
)

wordfreq_model.save('FrequencyModel.keras')
wordfreq_model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  SentenceInput (InputLayer)     [(32, 32, 9, 11, 27  0           []
#                                 6, 1)]
#
#  time_distributed_323 (TimeDist  (32, 32, 9, 11, 276  4          ['SentenceInput[0][0]']
#  ributed)                       , 1)
#
#  time_distributed_324 (TimeDist  (32, 32, 9, 11, 276  416        ['time_distributed_323[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_328 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_324[0][0]']
#  ributed)                        16)
#
#  time_distributed_327 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_324[0][0]']
#  ributed)                        16)
#
#  time_distributed_325 (TimeDist  (32, 32, 1, 1, 276,  544        ['time_distributed_327[0][0]',
#  ributed)                        32)                              'time_distributed_328[0][0]']
#
#  time_distributed_326 (TimeDist  (32, 32, 1, 1, 276,  528        ['time_distributed_325[0][0]',
#  ributed)                        16)                              'time_distributed_325[1][0]']
#
#  TimeAdd1 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_326[1][0]',
#                                  16)                              'time_distributed_326[0][0]']
#
#  TimeSigmoid1 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd1[0][0]']
#                                  16)
#
#  TimeAttnCreate1 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid1[0][0]',
#                                 , 16)                             'time_distributed_324[0][0]']
#
#  time_distributed_330 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  time_distributed_329 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  SpaceConcat1 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_330[0][0]',
#                                 16)                               'time_distributed_329[0][0]']
#
#  time_distributed_331 (TimeDist  (32, 32, 9, 11, 1,   65         ['SpaceConcat1[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate1 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_331[0][0]',
#                                 , 16)                             'TimeAttnCreate1[0][0]']
#
#  AttnApply1 (Add)               (32, 32, 9, 11, 276  0           ['SpaceAttnCreate1[0][0]',
#                                 , 16)                             'time_distributed_324[0][0]']
#
#  time_distributed_332 (TimeDist  (32, 32, 9, 11, 276  64         ['AttnApply1[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_333 (TimeDist  (32, 32, 9, 11, 276  12832      ['time_distributed_332[0][0]']
#  ributed)                       , 32)
#
#  time_distributed_337 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_333[0][0]']
#  ributed)                        32)
#
#  time_distributed_336 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_333[0][0]']
#  ributed)                        32)
#
#  time_distributed_334 (TimeDist  (32, 32, 1, 1, 276,  2112       ['time_distributed_336[0][0]',
#  ributed)                        64)                              'time_distributed_337[0][0]']
#
#  time_distributed_335 (TimeDist  (32, 32, 1, 1, 276,  2080       ['time_distributed_334[0][0]',
#  ributed)                        32)                              'time_distributed_334[1][0]']
#
#  TimeAdd4 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_335[1][0]',
#                                  32)                              'time_distributed_335[0][0]']
#
#  TimeSigmoid4 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd4[0][0]']
#                                  32)
#
#  TimeAttnCreate4 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid4[0][0]',
#                                 , 32)                             'time_distributed_333[0][0]']
#
#  time_distributed_339 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  time_distributed_338 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  SpaceConcat4 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_339[0][0]',
#                                 32)                               'time_distributed_338[0][0]']
#
#  time_distributed_340 (TimeDist  (32, 32, 9, 11, 1,   257        ['SpaceConcat4[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate4 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_340[0][0]',
#                                 , 32)                             'TimeAttnCreate4[0][0]']
#
#  TimeSpaceAttnApply4 (Add)      (32, 32, 9, 11, 276  0           ['SpaceAttnCreate4[0][0]',
#                                 , 32)                             'time_distributed_333[0][0]']
#
#  time_distributed_341 (TimeDist  (32, 32, 3, 3, 11,   0          ['TimeSpaceAttnApply4[0][0]']
#  ributed)                       32)
#
#  time_distributed_342 (TimeDist  (32, 32, 3168)      0           ['time_distributed_341[0][0]']
#  ributed)
#
#  time_distributed_343 (TimeDist  (32, 32, 64)        202816      ['time_distributed_342[0][0]']
#  ributed)
#
#  time_distributed_344 (TimeDist  (32, 32, 32)        2080        ['time_distributed_343[0][0]']
#  ributed)
#
#  time_distributed_345 (TimeDist  (32, 32, 64)        2112        ['time_distributed_344[0][0]']
#  ributed)
#
#  time_distributed_346 (TimeDist  (32, 32, 16)        1040        ['time_distributed_345[0][0]']
#  ributed)
#
#  time_distributed_347 (TimeDist  (32, 32, 1)         17          ['time_distributed_346[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 226,967
# Trainable params: 226,933
# Non-trainable params: 34
# __________________________________________________________________________________________________
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  SentenceInput (InputLayer)     [(32, 32, 9, 11, 27  0           []
#                                 6, 1)]
#
#  time_distributed_323 (TimeDist  (32, 32, 9, 11, 276  4          ['SentenceInput[0][0]']
#  ributed)                       , 1)
#
#  time_distributed_324 (TimeDist  (32, 32, 9, 11, 276  416        ['time_distributed_323[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_328 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_324[0][0]']
#  ributed)                        16)
#
#  time_distributed_327 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_324[0][0]']
#  ributed)                        16)
#
#  time_distributed_325 (TimeDist  (32, 32, 1, 1, 276,  544        ['time_distributed_327[0][0]',
#  ributed)                        32)                              'time_distributed_328[0][0]']
#
#  time_distributed_326 (TimeDist  (32, 32, 1, 1, 276,  528        ['time_distributed_325[0][0]',
#  ributed)                        16)                              'time_distributed_325[1][0]']
#
#  TimeAdd1 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_326[1][0]',
#                                  16)                              'time_distributed_326[0][0]']
#
#  TimeSigmoid1 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd1[0][0]']
#                                  16)
#
#  TimeAttnCreate1 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid1[0][0]',
#                                 , 16)                             'time_distributed_324[0][0]']
#
#  time_distributed_330 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  time_distributed_329 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  SpaceConcat1 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_330[0][0]',
#                                 16)                               'time_distributed_329[0][0]']
#
#  time_distributed_331 (TimeDist  (32, 32, 9, 11, 1,   65         ['SpaceConcat1[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate1 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_331[0][0]',
#                                 , 16)                             'TimeAttnCreate1[0][0]']
#
#  AttnApply1 (Add)               (32, 32, 9, 11, 276  0           ['SpaceAttnCreate1[0][0]',
#                                 , 16)                             'time_distributed_324[0][0]']
#
#  time_distributed_332 (TimeDist  (32, 32, 9, 11, 276  64         ['AttnApply1[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_333 (TimeDist  (32, 32, 9, 11, 276  12832      ['time_distributed_332[0][0]']
#  ributed)                       , 32)
#
#  time_distributed_337 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_333[0][0]']
#  ributed)                        32)
#
#  time_distributed_336 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_333[0][0]']
#  ributed)                        32)
#
#  time_distributed_334 (TimeDist  (32, 32, 1, 1, 276,  2112       ['time_distributed_336[0][0]',
#  ributed)                        64)                              'time_distributed_337[0][0]']
#
#  time_distributed_335 (TimeDist  (32, 32, 1, 1, 276,  2080       ['time_distributed_334[0][0]',
#  ributed)                        32)                              'time_distributed_334[1][0]']
#
#  TimeAdd4 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_335[1][0]',
#                                  32)                              'time_distributed_335[0][0]']
#
#  TimeSigmoid4 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd4[0][0]']
#                                  32)
#
#  TimeAttnCreate4 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid4[0][0]',
#                                 , 32)                             'time_distributed_333[0][0]']
#
#  time_distributed_339 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  time_distributed_338 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  SpaceConcat4 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_339[0][0]',
#                                 32)                               'time_distributed_338[0][0]']
#
#  time_distributed_340 (TimeDist  (32, 32, 9, 11, 1,   257        ['SpaceConcat4[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate4 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_340[0][0]',
#                                 , 32)                             'TimeAttnCreate4[0][0]']
#
#  TimeSpaceAttnApply4 (Add)      (32, 32, 9, 11, 276  0           ['SpaceAttnCreate4[0][0]',
#                                 , 32)                             'time_distributed_333[0][0]']
#
#  time_distributed_341 (TimeDist  (32, 32, 3, 3, 11,   0          ['TimeSpaceAttnApply4[0][0]']
#  ributed)                       32)
#
#  time_distributed_342 (TimeDist  (32, 32, 3168)      0           ['time_distributed_341[0][0]']
#  ributed)
#
#  time_distributed_343 (TimeDist  (32, 32, 64)        202816      ['time_distributed_342[0][0]']
#  ributed)
#
#  time_distributed_344 (TimeDist  (32, 32, 32)        2080        ['time_distributed_343[0][0]']
#  ributed)
#
#  time_distributed_345 (TimeDist  (32, 32, 64)        2112        ['time_distributed_344[0][0]']
#  ributed)
#
#  time_distributed_346 (TimeDist  (32, 32, 16)        1040        ['time_distributed_345[0][0]']
#  ributed)
#
#  time_distributed_347 (TimeDist  (32, 32, 1)         17          ['time_distributed_346[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 226,967
# Trainable params: 226,933
# Non-trainable params: 34
# __________________________________________________________________________________________________

# %% [markdown]
# Word Length Module

# %%
import keras
from keras import layers

CNN_input = keras.Input(shape=(32, 9, 11, 276, 1), batch_size=32, name = 'SentenceInput')

#Conv Block 1
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm1'))(CNN_input)
x = layers.TimeDistributed(layers.Conv3D(16, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv1'))(x)

#Find time attention for each channel
time_dense1 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense1_1'))
time_dense2 = layers.TimeDistributed(layers.Dense(16, activation = 'relu', name = 'TimeDense1_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool1'))(x)
fx_max = time_dense1(fx_max)
fx_max = time_dense2(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool1'))(x)
fx_avg = time_dense1(fx_avg)
fx_avg = time_dense2(fx_avg)

time_attention = layers.Add(name = 'TimeAdd1')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid1')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate1')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool1'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool1'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat1')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,1), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn1'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate1')([space_attention, fx])

#Apply Time and Space attention
block1out = layers.Add(name = 'AttnApply1')([fx, x])

# #Conv Block 2

# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm2'))(block1out)
# x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv2'))(x)

# #Find time attention for each channel
# time_dense3 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense2_1'))
# time_dense4 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense2_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool2'))(x)
# fx_max = time_dense3(fx_max)
# fx_max = time_dense4(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool2'))(x)
# fx_avg = time_dense3(fx_avg)
# fx_avg = time_dense4(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd2')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid2')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate2')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool2'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool2'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat2')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn2'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate2')([space_attention, fx])
# block2out = layers.Add(name = 'TimeSpaceAttnApply2')([fx, x])

# #Conv Block 3
# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm3'))(block2out)
# x = layers.TimeDistributed(layers.Conv3D(64, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv3'))(x)

# time_dense5 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense3_1'))
# time_dense6 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense3_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool3'))(x)
# fx_max = time_dense5(fx_max)
# fx_max = time_dense6(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool3'))(x)
# fx_avg = time_dense5(fx_avg)
# fx_avg = time_dense6(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd3')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid3')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate3')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool3'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SapceAvgPool3'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat3')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv3'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate3')([space_attention, fx])
# block3out = layers.Add(name = 'TimeSpaceAttnApply3')([fx, x])

#Conv Block 4

# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block3out)
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block1out)
x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv4'))(x)

time_dense7 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense4_1'))
time_dense8 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense4_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name='TimeMaxPool4'))(x)
fx_max = time_dense7(fx_max)
fx_max = time_dense8(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool4'))(x)
fx_avg = time_dense7(fx_avg)
fx_avg = time_dense8(fx_avg)

time_attention = layers.Add(name = 'TimeAdd4')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid4')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate4')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool4'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool4'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat4')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv4'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate4')([space_attention, fx])
block4out = layers.Add(name = 'TimeSpaceAttnApply4')([fx, x])

# Final word vector maker
x = layers.TimeDistributed(layers.MaxPool3D(pool_size = (3,3,25), name = 'FinalMaxPool'))(block4out)
x = layers.TimeDistributed(layers.Flatten(name = 'Flatten'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense1'))(x)
x = layers.TimeDistributed(layers.Dense(32, activation='relu', name = 'FinalDense2'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense3'))(x)
x = layers.TimeDistributed(layers.Dense(16, activation='relu', name = 'FinalDense4'))(x)
CNN_output = layers.TimeDistributed(layers.Dense(1, name = 'WordFormOutput'))(x)

wordform_model = keras.Model(CNN_input, CNN_output)

#Compile
wordform_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.MeanSquaredError(),
    metrics=[keras.metrics.MeanAbsoluteError()]
)

wordform_model.save('WordFormModel.keras')
wordform_model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  SentenceInput (InputLayer)     [(32, 32, 9, 11, 27  0           []
#                                 6, 1)]
#
#  time_distributed_348 (TimeDist  (32, 32, 9, 11, 276  4          ['SentenceInput[0][0]']
#  ributed)                       , 1)
#
#  time_distributed_349 (TimeDist  (32, 32, 9, 11, 276  416        ['time_distributed_348[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_353 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_349[0][0]']
#  ributed)                        16)
#
#  time_distributed_352 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_349[0][0]']
#  ributed)                        16)
#
#  time_distributed_350 (TimeDist  (32, 32, 1, 1, 276,  544        ['time_distributed_352[0][0]',
#  ributed)                        32)                              'time_distributed_353[0][0]']
#
#  time_distributed_351 (TimeDist  (32, 32, 1, 1, 276,  528        ['time_distributed_350[0][0]',
#  ributed)                        16)                              'time_distributed_350[1][0]']
#
#  TimeAdd1 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_351[1][0]',
#                                  16)                              'time_distributed_351[0][0]']
#
#  TimeSigmoid1 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd1[0][0]']
#                                  16)
#
#  TimeAttnCreate1 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid1[0][0]',
#                                 , 16)                             'time_distributed_349[0][0]']
#
#  time_distributed_355 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  time_distributed_354 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  SpaceConcat1 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_355[0][0]',
#                                 16)                               'time_distributed_354[0][0]']
#
#  time_distributed_356 (TimeDist  (32, 32, 9, 11, 1,   65         ['SpaceConcat1[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate1 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_356[0][0]',
#                                 , 16)                             'TimeAttnCreate1[0][0]']
#
#  AttnApply1 (Add)               (32, 32, 9, 11, 276  0           ['SpaceAttnCreate1[0][0]',
#                                 , 16)                             'time_distributed_349[0][0]']
#
#  time_distributed_357 (TimeDist  (32, 32, 9, 11, 276  64         ['AttnApply1[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_358 (TimeDist  (32, 32, 9, 11, 276  12832      ['time_distributed_357[0][0]']
#  ributed)                       , 32)
#
#  time_distributed_362 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_358[0][0]']
#  ributed)                        32)
#
#  time_distributed_361 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_358[0][0]']
#  ributed)                        32)
#
#  time_distributed_359 (TimeDist  (32, 32, 1, 1, 276,  2112       ['time_distributed_361[0][0]',
#  ributed)                        64)                              'time_distributed_362[0][0]']
#
#  time_distributed_360 (TimeDist  (32, 32, 1, 1, 276,  2080       ['time_distributed_359[0][0]',
#  ributed)                        32)                              'time_distributed_359[1][0]']
#
#  TimeAdd4 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_360[1][0]',
#                                  32)                              'time_distributed_360[0][0]']
#
#  TimeSigmoid4 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd4[0][0]']
#                                  32)
#
#  TimeAttnCreate4 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid4[0][0]',
#                                 , 32)                             'time_distributed_358[0][0]']
#
#  time_distributed_364 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  time_distributed_363 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  SpaceConcat4 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_364[0][0]',
#                                 32)                               'time_distributed_363[0][0]']
#
#  time_distributed_365 (TimeDist  (32, 32, 9, 11, 1,   257        ['SpaceConcat4[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate4 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_365[0][0]',
#                                 , 32)                             'TimeAttnCreate4[0][0]']
#
#  TimeSpaceAttnApply4 (Add)      (32, 32, 9, 11, 276  0           ['SpaceAttnCreate4[0][0]',
#                                 , 32)                             'time_distributed_358[0][0]']
#
#  time_distributed_366 (TimeDist  (32, 32, 3, 3, 11,   0          ['TimeSpaceAttnApply4[0][0]']
#  ributed)                       32)
#
#  time_distributed_367 (TimeDist  (32, 32, 3168)      0           ['time_distributed_366[0][0]']
#  ributed)
#
#  time_distributed_368 (TimeDist  (32, 32, 64)        202816      ['time_distributed_367[0][0]']
#  ributed)
#
#  time_distributed_369 (TimeDist  (32, 32, 32)        2080        ['time_distributed_368[0][0]']
#  ributed)
#
#  time_distributed_370 (TimeDist  (32, 32, 64)        2112        ['time_distributed_369[0][0]']
#  ributed)
#
#  time_distributed_371 (TimeDist  (32, 32, 16)        1040        ['time_distributed_370[0][0]']
#  ributed)
#
#  time_distributed_372 (TimeDist  (32, 32, 1)         17          ['time_distributed_371[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 226,967
# Trainable params: 226,933
# Non-trainable params: 34
# __________________________________________________________________________________________________

# %% [markdown]
# Semantic Vector Module

# %%
import keras
from keras import layers

CNN_input = keras.Input(shape=(32, 9, 11, 276, 1), batch_size=32, name = 'SentenceInput')

#Conv Block 1
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm1'))(CNN_input)
x = layers.TimeDistributed(layers.Conv3D(16, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv1'))(x)

#Find time attention for each channel
time_dense1 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense1_1'))
time_dense2 = layers.TimeDistributed(layers.Dense(16, activation = 'relu', name = 'TimeDense1_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool1'))(x)
fx_max = time_dense1(fx_max)
fx_max = time_dense2(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool1'))(x)
fx_avg = time_dense1(fx_avg)
fx_avg = time_dense2(fx_avg)

time_attention = layers.Add(name = 'TimeAdd1')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid1')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate1')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool1'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool1'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat1')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,1), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn1'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate1')([space_attention, fx])

#Apply Time and Space attention
block1out = layers.Add(name = 'AttnApply1')([fx, x])

# #Conv Block 2

# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm2'))(block1out)
# x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv2'))(x)

# #Find time attention for each channel
# time_dense3 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense2_1'))
# time_dense4 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense2_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool2'))(x)
# fx_max = time_dense3(fx_max)
# fx_max = time_dense4(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool2'))(x)
# fx_avg = time_dense3(fx_avg)
# fx_avg = time_dense4(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd2')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid2')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate2')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool2'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool2'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat2')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn2'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate2')([space_attention, fx])
# block2out = layers.Add(name = 'TimeSpaceAttnApply2')([fx, x])

# #Conv Block 3
# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm3'))(block2out)
# x = layers.TimeDistributed(layers.Conv3D(64, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv3'))(x)

# time_dense5 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense3_1'))
# time_dense6 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense3_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool3'))(x)
# fx_max = time_dense5(fx_max)
# fx_max = time_dense6(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool3'))(x)
# fx_avg = time_dense5(fx_avg)
# fx_avg = time_dense6(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd3')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid3')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate3')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool3'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SapceAvgPool3'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat3')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv3'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate3')([space_attention, fx])
# block3out = layers.Add(name = 'TimeSpaceAttnApply3')([fx, x])

#Conv Block 4

#x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block3out)
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block1out)
x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv4'))(x)

time_dense7 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense4_1'))
time_dense8 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense4_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name='TimeMaxPool4'))(x)
fx_max = time_dense7(fx_max)
fx_max = time_dense8(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool4'))(x)
fx_avg = time_dense7(fx_avg)
fx_avg = time_dense8(fx_avg)

time_attention = layers.Add(name = 'TimeAdd4')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid4')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate4')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool4'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool4'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat4')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv4'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate4')([space_attention, fx])
block4out = layers.Add(name = 'TimeSpaceAttnApply4')([fx, x])

# Final word vector maker
x = layers.TimeDistributed(layers.MaxPool3D(pool_size = (3,3,25), name = 'FinalMaxPool'))(block4out)
x = layers.TimeDistributed(layers.Flatten(name = 'Flatten'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense1'))(x)
x = layers.TimeDistributed(layers.Dense(32, activation='relu', name = 'FinalDense2'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense3'))(x)
x = layers.TimeDistributed(layers.Dense(300, name = 'WordVectorOutput'))(x)
CNN_output = layers.TimeDistributed(layers.BatchNormalization(axis=-1))(x)

semantic_encoder = keras.Model(CNN_input, CNN_output)

#Compile
semantic_encoder.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.CosineSimilarity(),
    metrics=[keras.metrics.MeanSquaredError(), keras.metrics.CosineSimilarity()]
)

semantic_encoder.save('SemanticModel.keras')
semantic_encoder.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  SentenceInput (InputLayer)     [(32, 32, 9, 11, 27  0           []
#                                 6, 1)]
#
#  time_distributed_373 (TimeDist  (32, 32, 9, 11, 276  4          ['SentenceInput[0][0]']
#  ributed)                       , 1)
#
#  time_distributed_374 (TimeDist  (32, 32, 9, 11, 276  416        ['time_distributed_373[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_378 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_374[0][0]']
#  ributed)                        16)
#
#  time_distributed_377 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_374[0][0]']
#  ributed)                        16)
#
#  time_distributed_375 (TimeDist  (32, 32, 1, 1, 276,  544        ['time_distributed_377[0][0]',
#  ributed)                        32)                              'time_distributed_378[0][0]']
#
#  time_distributed_376 (TimeDist  (32, 32, 1, 1, 276,  528        ['time_distributed_375[0][0]',
#  ributed)                        16)                              'time_distributed_375[1][0]']
#
#  TimeAdd1 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_376[1][0]',
#                                  16)                              'time_distributed_376[0][0]']
#
#  TimeSigmoid1 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd1[0][0]']
#                                  16)
#
#  TimeAttnCreate1 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid1[0][0]',
#                                 , 16)                             'time_distributed_374[0][0]']
#
#  time_distributed_380 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  time_distributed_379 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  SpaceConcat1 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_380[0][0]',
#                                 16)                               'time_distributed_379[0][0]']
#
#  time_distributed_381 (TimeDist  (32, 32, 9, 11, 1,   65         ['SpaceConcat1[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate1 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_381[0][0]',
#                                 , 16)                             'TimeAttnCreate1[0][0]']
#
#  AttnApply1 (Add)               (32, 32, 9, 11, 276  0           ['SpaceAttnCreate1[0][0]',
#                                 , 16)                             'time_distributed_374[0][0]']
#
#  time_distributed_382 (TimeDist  (32, 32, 9, 11, 276  64         ['AttnApply1[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_383 (TimeDist  (32, 32, 9, 11, 276  12832      ['time_distributed_382[0][0]']
#  ributed)                       , 32)
#
#  time_distributed_387 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_383[0][0]']
#  ributed)                        32)
#
#  time_distributed_386 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_383[0][0]']
#  ributed)                        32)
#
#  time_distributed_384 (TimeDist  (32, 32, 1, 1, 276,  2112       ['time_distributed_386[0][0]',
#  ributed)                        64)                              'time_distributed_387[0][0]']
#
#  time_distributed_385 (TimeDist  (32, 32, 1, 1, 276,  2080       ['time_distributed_384[0][0]',
#  ributed)                        32)                              'time_distributed_384[1][0]']
#
#  TimeAdd4 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_385[1][0]',
#                                  32)                              'time_distributed_385[0][0]']
#
#  TimeSigmoid4 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd4[0][0]']
#                                  32)
#
#  TimeAttnCreate4 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid4[0][0]',
#                                 , 32)                             'time_distributed_383[0][0]']
#
#  time_distributed_389 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  time_distributed_388 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  SpaceConcat4 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_389[0][0]',
#                                 32)                               'time_distributed_388[0][0]']
#
#  time_distributed_390 (TimeDist  (32, 32, 9, 11, 1,   257        ['SpaceConcat4[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate4 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_390[0][0]',
#                                 , 32)                             'TimeAttnCreate4[0][0]']
#
#  TimeSpaceAttnApply4 (Add)      (32, 32, 9, 11, 276  0           ['SpaceAttnCreate4[0][0]',
#                                 , 32)                             'time_distributed_383[0][0]']
#
#  time_distributed_391 (TimeDist  (32, 32, 3, 3, 11,   0          ['TimeSpaceAttnApply4[0][0]']
#  ributed)                       32)
#
#  time_distributed_392 (TimeDist  (32, 32, 3168)      0           ['time_distributed_391[0][0]']
#  ributed)
#
#  time_distributed_393 (TimeDist  (32, 32, 64)        202816      ['time_distributed_392[0][0]']
#  ributed)
#
#  time_distributed_394 (TimeDist  (32, 32, 32)        2080        ['time_distributed_393[0][0]']
#  ributed)
#
#  time_distributed_395 (TimeDist  (32, 32, 64)        2112        ['time_distributed_394[0][0]']
#  ributed)
#
#  time_distributed_396 (TimeDist  (32, 32, 300)       19500       ['time_distributed_395[0][0]']
#  ributed)
#
#  time_distributed_397 (TimeDist  (32, 32, 300)       1200        ['time_distributed_396[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 246,610
# Trainable params: 245,976
# Non-trainable params: 634
# __________________________________________________________________________________________________

# %% [markdown]
# Part of Speech Module

# %%
import keras
from keras import layers

CNN_input = keras.Input(shape=(32, 9, 11, 276, 1), batch_size=32, name = 'SentenceInput')

#Conv Block 1
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm1'))(CNN_input)
x = layers.TimeDistributed(layers.Conv3D(16, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv1'))(x)

#Find time attention for each channel
time_dense1 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense1_1'))
time_dense2 = layers.TimeDistributed(layers.Dense(16, activation = 'relu', name = 'TimeDense1_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool1'))(x)
fx_max = time_dense1(fx_max)
fx_max = time_dense2(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool1'))(x)
fx_avg = time_dense1(fx_avg)
fx_avg = time_dense2(fx_avg)

time_attention = layers.Add(name = 'TimeAdd1')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid1')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate1')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool1'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool1'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat1')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,1), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn1'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate1')([space_attention, fx])

#Apply Time and Space attention
block1out = layers.Add(name = 'AttnApply1')([fx, x])

# #Conv Block 2

# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm2'))(block1out)
# x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv2'))(x)

# #Find time attention for each channel
# time_dense3 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense2_1'))
# time_dense4 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense2_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool2'))(x)
# fx_max = time_dense3(fx_max)
# fx_max = time_dense4(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool2'))(x)
# fx_avg = time_dense3(fx_avg)
# fx_avg = time_dense4(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd2')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid2')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate2')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool2'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool2'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat2')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn2'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate2')([space_attention, fx])
# block2out = layers.Add(name = 'TimeSpaceAttnApply2')([fx, x])

# #Conv Block 3
# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm3'))(block2out)
# x = layers.TimeDistributed(layers.Conv3D(64, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv3'))(x)

# time_dense5 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense3_1'))
# time_dense6 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense3_2'))

# fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool3'))(x)
# fx_max = time_dense5(fx_max)
# fx_max = time_dense6(fx_max)

# fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool3'))(x)
# fx_avg = time_dense5(fx_avg)
# fx_avg = time_dense6(fx_avg)

# time_attention = layers.Add(name = 'TimeAdd3')([fx_avg, fx_max])
# time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid3')(time_attention)

# fx = layers.Multiply(name = 'TimeAttnCreate3')([time_attention, x])

# #Find space attention for each channel
# fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool3'))(fx)
# fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SapceAvgPool3'))(fx)
# space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat3')([fx_avg_space, fx_max_space])
# space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv3'))(space_attention)

# fx = layers.Multiply(name = 'SpaceAttnCreate3')([space_attention, fx])
# block3out = layers.Add(name = 'TimeSpaceAttnApply3')([fx, x])

#Conv Block 4

# x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block3out)
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block1out)
x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv4'))(x)

time_dense7 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense4_1'))
time_dense8 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense4_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name='TimeMaxPool4'))(x)
fx_max = time_dense7(fx_max)
fx_max = time_dense8(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool4'))(x)
fx_avg = time_dense7(fx_avg)
fx_avg = time_dense8(fx_avg)

time_attention = layers.Add(name = 'TimeAdd4')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid4')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate4')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool4'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool4'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat4')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv4'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate4')([space_attention, fx])
block4out = layers.Add(name = 'TimeSpaceAttnApply4')([fx, x])

# Final word vector maker
x = layers.TimeDistributed(layers.MaxPool3D(pool_size = (3,3,25), name = 'FinalMaxPool'))(block4out)
x = layers.TimeDistributed(layers.Flatten(name = 'Flatten'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense1'))(x)
x = layers.TimeDistributed(layers.Dense(32, activation='relu', name = 'FinalDense2'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense3'))(x)
CNN_output = layers.TimeDistributed(layers.Dense(18, name = 'PosOutput', activation='softmax'))(x)

pos_model = keras.Model(CNN_input, CNN_output)

pos_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-8),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy(), keras.metrics.SparseTopKCategoricalAccuracy(k=3)]
)

pos_model.save('PosModel.keras')
pos_model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  SentenceInput (InputLayer)     [(32, 32, 9, 11, 27  0           []
#                                 6, 1)]
#
#  time_distributed_398 (TimeDist  (32, 32, 9, 11, 276  4          ['SentenceInput[0][0]']
#  ributed)                       , 1)
#
#  time_distributed_399 (TimeDist  (32, 32, 9, 11, 276  416        ['time_distributed_398[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_403 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_399[0][0]']
#  ributed)                        16)
#
#  time_distributed_402 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_399[0][0]']
#  ributed)                        16)
#
#  time_distributed_400 (TimeDist  (32, 32, 1, 1, 276,  544        ['time_distributed_402[0][0]',
#  ributed)                        32)                              'time_distributed_403[0][0]']
#
#  time_distributed_401 (TimeDist  (32, 32, 1, 1, 276,  528        ['time_distributed_400[0][0]',
#  ributed)                        16)                              'time_distributed_400[1][0]']
#
#  TimeAdd1 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_401[1][0]',
#                                  16)                              'time_distributed_401[0][0]']
#
#  TimeSigmoid1 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd1[0][0]']
#                                  16)
#
#  TimeAttnCreate1 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid1[0][0]',
#                                 , 16)                             'time_distributed_399[0][0]']
#
#  time_distributed_405 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  time_distributed_404 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate1[0][0]']
#  ributed)                       16)
#
#  SpaceConcat1 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_405[0][0]',
#                                 16)                               'time_distributed_404[0][0]']
#
#  time_distributed_406 (TimeDist  (32, 32, 9, 11, 1,   65         ['SpaceConcat1[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate1 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_406[0][0]',
#                                 , 16)                             'TimeAttnCreate1[0][0]']
#
#  AttnApply1 (Add)               (32, 32, 9, 11, 276  0           ['SpaceAttnCreate1[0][0]',
#                                 , 16)                             'time_distributed_399[0][0]']
#
#  time_distributed_407 (TimeDist  (32, 32, 9, 11, 276  64         ['AttnApply1[0][0]']
#  ributed)                       , 16)
#
#  time_distributed_408 (TimeDist  (32, 32, 9, 11, 276  12832      ['time_distributed_407[0][0]']
#  ributed)                       , 32)
#
#  time_distributed_412 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_408[0][0]']
#  ributed)                        32)
#
#  time_distributed_411 (TimeDist  (32, 32, 1, 1, 276,  0          ['time_distributed_408[0][0]']
#  ributed)                        32)
#
#  time_distributed_409 (TimeDist  (32, 32, 1, 1, 276,  2112       ['time_distributed_411[0][0]',
#  ributed)                        64)                              'time_distributed_412[0][0]']
#
#  time_distributed_410 (TimeDist  (32, 32, 1, 1, 276,  2080       ['time_distributed_409[0][0]',
#  ributed)                        32)                              'time_distributed_409[1][0]']
#
#  TimeAdd4 (Add)                 (32, 32, 1, 1, 276,  0           ['time_distributed_410[1][0]',
#                                  32)                              'time_distributed_410[0][0]']
#
#  TimeSigmoid4 (Activation)      (32, 32, 1, 1, 276,  0           ['TimeAdd4[0][0]']
#                                  32)
#
#  TimeAttnCreate4 (Multiply)     (32, 32, 9, 11, 276  0           ['TimeSigmoid4[0][0]',
#                                 , 32)                             'time_distributed_408[0][0]']
#
#  time_distributed_414 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  time_distributed_413 (TimeDist  (32, 32, 9, 11, 1,   0          ['TimeAttnCreate4[0][0]']
#  ributed)                       32)
#
#  SpaceConcat4 (Concatenate)     (32, 32, 9, 22, 1,   0           ['time_distributed_414[0][0]',
#                                 32)                               'time_distributed_413[0][0]']
#
#  time_distributed_415 (TimeDist  (32, 32, 9, 11, 1,   257        ['SpaceConcat4[0][0]']
#  ributed)                       1)
#
#  SpaceAttnCreate4 (Multiply)    (32, 32, 9, 11, 276  0           ['time_distributed_415[0][0]',
#                                 , 32)                             'TimeAttnCreate4[0][0]']
#
#  TimeSpaceAttnApply4 (Add)      (32, 32, 9, 11, 276  0           ['SpaceAttnCreate4[0][0]',
#                                 , 32)                             'time_distributed_408[0][0]']
#
#  time_distributed_416 (TimeDist  (32, 32, 3, 3, 11,   0          ['TimeSpaceAttnApply4[0][0]']
#  ributed)                       32)
#
#  time_distributed_417 (TimeDist  (32, 32, 3168)      0           ['time_distributed_416[0][0]']
#  ributed)
#
#  time_distributed_418 (TimeDist  (32, 32, 64)        202816      ['time_distributed_417[0][0]']
#  ributed)
#
#  time_distributed_419 (TimeDist  (32, 32, 32)        2080        ['time_distributed_418[0][0]']
#  ributed)
#
#  time_distributed_420 (TimeDist  (32, 32, 64)        2112        ['time_distributed_419[0][0]']
#  ributed)
#
#  time_distributed_421 (TimeDist  (32, 32, 18)        1170        ['time_distributed_420[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 227,080
# Trainable params: 227,046
# Non-trainable params: 34
# __________________________________________________________________________________________________
