# %%
# !pip install mne datasets evaluate

# %%
# !pip install numpy==1.23.0

# %%
import mne
import random
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
import os
import evaluate
import datasets
from datasets import load_dataset
from huggingface_hub import hf_hub_download, login

# %%
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
hf_hub_download(repo_id="groshanr/EEG2Text-Raw", filename="Murphyetal.zip", repo_type="dataset")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Murphyetal.zip:   0%|          | 0.00/26.5G [00:00<?, ?B/s]
# '/root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal.zip'

# %%
# %cd /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8
# Out:
# /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8

# %%
# !unzip Murphyetal.zip
# Out:
# Archive:  Murphyetal.zip
#    creating: Murphyetal/
#   inflating: Murphyetal/rsvp_session4_files31-44-epo.fif
#   inflating: Murphyetal/rsvp_session2_files37-42-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files37-42-epo.fif
#   inflating: Murphyetal/rsvp_session3_files25-29-epo.fif
#   inflating: Murphyetal/rsvp_session1_files10-18-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files10-18-epo.fif
#   inflating: Murphyetal/rsvp_session4_files21-30-epo.fif
#   inflating: Murphyetal/rsvp_session2_files76-88-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files76-88-epo.fif
#   inflating: Murphyetal/rsvp_session2_files67-75-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files67-75-epo.fif
#   inflating: Murphyetal/rsvp_session2_files105-113-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files105-113-epo.fif
#   inflating: Murphyetal/rsvp_session0_files89-94-epo.fif
#   inflating: Murphyetal/rsvp_session1_files0-9-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files0-9-epo.fif
#   inflating: Murphyetal/rsvp_session4_files139-147-epo.fif
#   inflating: Murphyetal/rsvp_session4_files13-20-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files13-20-epo.fif
#   inflating: Murphyetal/rsvp_session2_files43-48-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files43-48-epo.fif
#   inflating: Murphyetal/rsvp_session0_files95-104-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files95-104-epo.fif
#   inflating: Murphyetal/rsvp_session1_files106-122-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files106-122-epo.fif
#   inflating: Murphyetal/rsvp_session5_files0-8-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files0-8-epo.fif
#   inflating: Murphyetal/rsvp_session1_files45-54-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files45-54-epo.fif
#   inflating: Murphyetal/rsvp_session1_files141-151-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files141-151-epo.fif
#   inflating: Murphyetal/rsvp_session4_files83-89-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files83-89-epo.fif
#   inflating: Murphyetal/rsvp_session3_files0-7-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files0-7-epo.fif
#   inflating: Murphyetal/rsvp_session4_files148-151-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files148-151-epo.fif
#   inflating: Murphyetal/rsvp_session3_files140-151-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files140-151-epo.fif
#   inflating: Murphyetal/rsvp_session0_files126-134-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files126-134-epo.fif
#   inflating: Murphyetal/rsvp_session0_files40-50-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files40-50-epo.fif
#   inflating: Murphyetal/rsvp_session2_files14-29-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files14-29-epo.fif
#   inflating: Murphyetal/rsvp_session0_files12-22-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files12-22-epo.fif
#   inflating: Murphyetal/rsvp_session4_files124-138-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files124-138-epo.fif
#   inflating: Murphyetal/rsvp_session1_files19-33-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files19-33-epo.fif
#   inflating: Murphyetal/rsvp_session1_files93-105-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files93-105-epo.fif
#   inflating: Murphyetal/rsvp_session1_files132-140-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files132-140-epo.fif
#   inflating: Murphyetal/rsvp_session3_files84-100-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files84-100-epo.fif
#   inflating: Murphyetal/rsvp_session4_files45-54-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files45-54-epo.fif
#   inflating: Murphyetal/rsvp_session5_files62-68-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files62-68-epo.fif
#   inflating: Murphyetal/rsvp_session2_files140-151-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files140-151-epo.fif
#   inflating: Murphyetal/rsvp_session5_files69-81-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files69-81-epo.fif
#   inflating: Murphyetal/rsvp_session4_files102-110-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files102-110-epo.fif
#   inflating: Murphyetal/rsvp_session1_files55-67-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files55-67-epo.fif
#   inflating: Murphyetal/rsvp_session1_files34-44-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files34-44-epo.fif
#   inflating: Murphyetal/rsvp_session0_files74-88-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files74-88-epo.fif
#   inflating: Murphyetal/rsvp_session0_files29-39-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files29-39-epo.fif
#   inflating: Murphyetal/rsvp_session5_files22-37-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files22-37-epo.fif
#   inflating: Murphyetal/rsvp_session3_files30-42-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files30-42-epo.fif
#   inflating: Murphyetal/rsvp_session4_files55-71-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files55-71-epo.fif
#   inflating: Murphyetal/rsvp_session3_files67-83-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files67-83-epo.fif
#   inflating: Murphyetal/rsvp_session4_files0-12-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files0-12-epo.fif
#   inflating: Murphyetal/rsvp_session5_files38-50-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files38-50-epo.fif
#   inflating: Murphyetal/rsvp_session5_files82-94-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files82-94-epo.fif
#   inflating: Murphyetal/rsvp_session0_files135-142-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files135-142-epo.fif
#   inflating: Murphyetal/rsvp_session3_files114-119-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files114-119-epo.fif
#   inflating: Murphyetal/rsvp_session2_files89-97-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files89-97-epo.fif
#   inflating: Murphyetal/rsvp_session2_files128-139-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files128-139-epo.fif
#   inflating: Murphyetal/rsvp_session2_files98-104-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files98-104-epo.fif
#   inflating: Murphyetal/rsvp_session1_files68-71-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files68-71-epo.fif
#   inflating: Murphyetal/rsvp_session0_files105-112-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files105-112-epo.fif
#   inflating: Murphyetal/rsvp_session0_files143-151-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files143-151-epo.fif
#   inflating: Murphyetal/rsvp_session4_files72-82-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files72-82-epo.fif
#   inflating: Murphyetal/rsvp_session0_files51-73-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files51-73-epo.fif
#   inflating: Murphyetal/rsvp_session4_files111-123-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files111-123-epo.fif
#   inflating: Murphyetal/rsvp_session0_files0-11-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files0-11-epo.fif
#   inflating: Murphyetal/rsvp_session4_files90-101-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session4_files90-101-epo.fif
#   inflating: Murphyetal/rsvp_session2_files114-127-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files114-127-epo.fif
#   inflating: Murphyetal/rsvp_session3_files8-24-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files8-24-epo.fif
#   inflating: Murphyetal/rsvp_session2_files30-36-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files30-36-epo.fif
#   inflating: Murphyetal/rsvp_session3_files43-51-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files43-51-epo.fif
#   inflating: Murphyetal/rsvp_session3_files120-127-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files120-127-epo.fif
#   inflating: Murphyetal/rsvp_session0_files23-28-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files23-28-epo.fif
#   inflating: Murphyetal/rsvp_session2_files0-13-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session2_files0-13-epo.fif
#   inflating: Murphyetal/rsvp_session5_files9-21-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files9-21-epo.fif
#   inflating: Murphyetal/rsvp_session3_files52-66-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files52-66-epo.fif
#   inflating: Murphyetal/rsvp_session5_files51-61-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session5_files51-61-epo.fif
#   inflating: Murphyetal/rsvp_session0_files113-125-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session0_files113-125-epo.fif
#   inflating: Murphyetal/rsvp_session1_files72-92-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session1_files72-92-epo.fif
#   inflating: Murphyetal/rsvp_session3_files101-113-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files101-113-epo.fif
#   inflating: Murphyetal/rsvp_session3_files128-139-epo.fif
#   inflating: __MACOSX/Murphyetal/._rsvp_session3_files128-139-epo.fif

# %%
directory = '/root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal'
epoch_files = []

for root, dirs, files in os.walk(directory):
	for filename in files:
		if filename.endswith('.fif'):
				epoch_files.append(os.path.join(root, filename))

# %%
subsample = random.sample(epoch_files, 1)

# %%
epoch_list = []
for f in subsample:
    epoch_list.append(mne.read_epochs(f))
# Out:
# Reading /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal/rsvp_session1_files0-9-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64) active
#     Found the data of interest:
#         t =    -200.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 16 columns
# 4767 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal/rsvp_session5_files82-94-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64) active
#     Found the data of interest:
#         t =    -200.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 16 columns
# 5400 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal/rsvp_session4_files111-123-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64) active
#     Found the data of interest:
#         t =    -200.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 16 columns
# 5588 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal/rsvp_session1_files93-105-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64) active
#     Found the data of interest:
#         t =    -200.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 16 columns
# 6121 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading /root/.cache/huggingface/hub/datasets--groshanr--EEG2Text-Raw/snapshots/2d4b1ce038376e84109a5bbe8d24df6377f439c8/Murphyetal/rsvp_session3_files25-29-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64) active
#     Found the data of interest:
#         t =    -200.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 16 columns
# 5528 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated

# %%
epochs = mne.concatenate_epochs(epoch_list)
# Out:
# Adding metadata with 16 columns
# 27404 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)

# %%
epochs_df = epochs.to_data_frame()

# %%
metadata = epochs.metadata

# %%
import keras
from keras import layers

CNN_input = keras.Input(shape=(32, 9, 11, 276, 1), batch_size=32, name = 'SentenceInput')

#Conv Block 1
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm1'))(CNN_input)
x = layers.TimeDistributed(layers.Conv3D(16, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv1'))(x)

#Find time attention for each channel
time_dense1 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense1_1'))
time_dense2 = layers.TimeDistributed(layers.Dense(16, activation = 'relu', name = 'TimeDense1_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool1'))(x)
fx_max = time_dense1(fx_max)
fx_max = time_dense2(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool1'))(x)
fx_avg = time_dense1(fx_avg)
fx_avg = time_dense2(fx_avg)

time_attention = layers.Add(name = 'TimeAdd1')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid1')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate1')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool1'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool1'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat1')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,1), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn1'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate1')([space_attention, fx])

#Apply Time and Space attention
block1out = layers.Add(name = 'AttnApply1')([fx, x])

#Conv Block 2

x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm2'))(block1out)
x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv2'))(x)

#Find time attention for each channel
time_dense3 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense2_1'))
time_dense4 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense2_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool2'))(x)
fx_max = time_dense3(fx_max)
fx_max = time_dense4(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool2'))(x)
fx_avg = time_dense3(fx_avg)
fx_avg = time_dense4(fx_avg)

time_attention = layers.Add(name = 'TimeAdd2')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid2')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate2')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool2'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool2'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat2')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConvAttn2'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate2')([space_attention, fx])
block2out = layers.Add(name = 'TimeSpaceAttnApply2')([fx, x])

#Conv Block 3
x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm3'))(block2out)
x = layers.TimeDistributed(layers.Conv3D(64, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv3'))(x)

time_dense5 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense3_1'))
time_dense6 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense3_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name = 'TimeMaxPool3'))(x)
fx_max = time_dense5(fx_max)
fx_max = time_dense6(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool3'))(x)
fx_avg = time_dense5(fx_avg)
fx_avg = time_dense6(fx_avg)

time_attention = layers.Add(name = 'TimeAdd3')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid3')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate3')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool3'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SapceAvgPool3'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat3')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv3'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate3')([space_attention, fx])
block3out = layers.Add(name = 'TimeSpaceAttnApply3')([fx, x])

#Conv Block 4

x = layers.TimeDistributed(layers.BatchNormalization(name = 'BatchNorm4'))(block3out)
x = layers.TimeDistributed(layers.Conv3D(32, kernel_size=(5,5, 1), strides=1, padding = 'same', activation='relu', name = 'Conv4'))(x)

time_dense7 = layers.TimeDistributed(layers.Dense(64, activation = 'relu', name = 'TimeDense4_1'))
time_dense8 = layers.TimeDistributed(layers.Dense(32, activation = 'relu', name = 'TimeDense4_2'))

fx_max = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (9, 11, 1), name='TimeMaxPool4'))(x)
fx_max = time_dense7(fx_max)
fx_max = time_dense8(fx_max)

fx_avg = layers.TimeDistributed(layers.AveragePooling3D(pool_size= (9, 11, 1), name = 'TimeAvgPool4'))(x)
fx_avg = time_dense7(fx_avg)
fx_avg = time_dense8(fx_avg)

time_attention = layers.Add(name = 'TimeAdd4')([fx_avg, fx_max])
time_attention = layers.Activation('sigmoid', name = 'TimeSigmoid4')(time_attention)

fx = layers.Multiply(name = 'TimeAttnCreate4')([time_attention, x])

#Find space attention for each channel
fx_max_space = layers.TimeDistributed(layers.MaxPooling3D(pool_size = (1,1,276), name = 'SpaceMaxPool4'))(fx)
fx_avg_space = layers.TimeDistributed(layers.AveragePooling3D(pool_size = (1,1,276), name = 'SpaceAvgPool4'))(fx)
space_attention = layers.Concatenate(axis = 3, name = 'SpaceConcat4')([fx_avg_space, fx_max_space])
space_attention = layers.TimeDistributed(layers.Conv3D(filters = 1, kernel_size = (2,2,2), strides = (1,2,1), padding= 'same', activation='sigmoid', name = 'SpaceConv4'))(space_attention)

fx = layers.Multiply(name = 'SpaceAttnCreate4')([space_attention, fx])
block4out = layers.Add(name = 'TimeSpaceAttnApply4')([fx, x])

# Final word vector maker
x = layers.TimeDistributed(layers.MaxPool3D(pool_size = (3,3,25), name = 'FinalMaxPool'))(block4out)
x = layers.TimeDistributed(layers.Flatten(name = 'Flatten'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense1'))(x)
x = layers.TimeDistributed(layers.Dense(32, activation='relu', name = 'FinalDense2'))(x)
x = layers.TimeDistributed(layers.Dense(64, activation='relu', name = 'FinalDense3'))(x)
x = layers.TimeDistributed(layers.Dense(1, name = 'WordFreqOutput'))(x)
CNN_output = layers.TimeDistributed(layers.Normalization(axis=-1, name = 'Word Freq Normalization'))(x)

wordfreq_model = keras.Model(CNN_input, CNN_output)
wordfreq_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ SentenceInput             │ (32, 32, 9, 11, 276,   │              0 │ -                      │
# │ (InputLayer)              │ 1)                     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed          │ (32, 32, 9, 11, 276,   │              4 │ SentenceInput[0][0]    │
# │ (TimeDistributed)         │ 1)                     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_1        │ (32, 32, 9, 11, 276,   │            416 │ time_distributed[0][0] │
# │ (TimeDistributed)         │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_5        │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_1[0]… │
# │ (TimeDistributed)         │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_4        │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_1[0]… │
# │ (TimeDistributed)         │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_2        │ (32, 32, 1, 1, 276,    │            544 │ time_distributed_4[0]… │
# │ (TimeDistributed)         │ 32)                    │                │ time_distributed_5[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_3        │ (32, 32, 1, 1, 276,    │            528 │ time_distributed_2[0]… │
# │ (TimeDistributed)         │ 16)                    │                │ time_distributed_2[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAdd1 (Add)            │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_3[1]… │
# │                           │ 16)                    │                │ time_distributed_3[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSigmoid1 (Activation) │ (32, 32, 1, 1, 276,    │              0 │ TimeAdd1[0][0]         │
# │                           │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAttnCreate1           │ (32, 32, 9, 11, 276,   │              0 │ TimeSigmoid1[0][0],    │
# │ (Multiply)                │ 16)                    │                │ time_distributed_1[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_7        │ (32, 32, 9, 11, 1, 16) │              0 │ TimeAttnCreate1[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_6        │ (32, 32, 9, 11, 1, 16) │              0 │ TimeAttnCreate1[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceConcat1              │ (32, 32, 9, 22, 1, 16) │              0 │ time_distributed_7[0]… │
# │ (Concatenate)             │                        │                │ time_distributed_6[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_8        │ (32, 32, 9, 11, 1, 1)  │             65 │ SpaceConcat1[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceAttnCreate1          │ (32, 32, 9, 11, 276,   │              0 │ time_distributed_8[0]… │
# │ (Multiply)                │ 16)                    │                │ TimeAttnCreate1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AttnApply1 (Add)          │ (32, 32, 9, 11, 276,   │              0 │ SpaceAttnCreate1[0][0… │
# │                           │ 16)                    │                │ time_distributed_1[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_9        │ (32, 32, 9, 11, 276,   │             64 │ AttnApply1[0][0]       │
# │ (TimeDistributed)         │ 16)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_10       │ (32, 32, 9, 11, 276,   │         12,832 │ time_distributed_9[0]… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_14       │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_10[0… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_13       │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_10[0… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_11       │ (32, 32, 1, 1, 276,    │          2,112 │ time_distributed_13[0… │
# │ (TimeDistributed)         │ 64)                    │                │ time_distributed_14[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_12       │ (32, 32, 1, 1, 276,    │          2,080 │ time_distributed_11[0… │
# │ (TimeDistributed)         │ 32)                    │                │ time_distributed_11[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAdd2 (Add)            │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_12[1… │
# │                           │ 32)                    │                │ time_distributed_12[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSigmoid2 (Activation) │ (32, 32, 1, 1, 276,    │              0 │ TimeAdd2[0][0]         │
# │                           │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAttnCreate2           │ (32, 32, 9, 11, 276,   │              0 │ TimeSigmoid2[0][0],    │
# │ (Multiply)                │ 32)                    │                │ time_distributed_10[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_16       │ (32, 32, 9, 11, 1, 32) │              0 │ TimeAttnCreate2[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_15       │ (32, 32, 9, 11, 1, 32) │              0 │ TimeAttnCreate2[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceConcat2              │ (32, 32, 9, 22, 1, 32) │              0 │ time_distributed_16[0… │
# │ (Concatenate)             │                        │                │ time_distributed_15[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_17       │ (32, 32, 9, 11, 1, 1)  │            257 │ SpaceConcat2[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceAttnCreate2          │ (32, 32, 9, 11, 276,   │              0 │ time_distributed_17[0… │
# │ (Multiply)                │ 32)                    │                │ TimeAttnCreate2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSpaceAttnApply2 (Add) │ (32, 32, 9, 11, 276,   │              0 │ SpaceAttnCreate2[0][0… │
# │                           │ 32)                    │                │ time_distributed_10[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_18       │ (32, 32, 9, 11, 276,   │            128 │ TimeSpaceAttnApply2[0… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_19       │ (32, 32, 9, 11, 276,   │         51,264 │ time_distributed_18[0… │
# │ (TimeDistributed)         │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_23       │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_19[0… │
# │ (TimeDistributed)         │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_22       │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_19[0… │
# │ (TimeDistributed)         │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_20       │ (32, 32, 1, 1, 276,    │          2,080 │ time_distributed_22[0… │
# │ (TimeDistributed)         │ 32)                    │                │ time_distributed_23[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_21       │ (32, 32, 1, 1, 276,    │          2,112 │ time_distributed_20[0… │
# │ (TimeDistributed)         │ 64)                    │                │ time_distributed_20[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAdd3 (Add)            │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_21[1… │
# │                           │ 64)                    │                │ time_distributed_21[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSigmoid3 (Activation) │ (32, 32, 1, 1, 276,    │              0 │ TimeAdd3[0][0]         │
# │                           │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAttnCreate3           │ (32, 32, 9, 11, 276,   │              0 │ TimeSigmoid3[0][0],    │
# │ (Multiply)                │ 64)                    │                │ time_distributed_19[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_25       │ (32, 32, 9, 11, 1, 64) │              0 │ TimeAttnCreate3[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_24       │ (32, 32, 9, 11, 1, 64) │              0 │ TimeAttnCreate3[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceConcat3              │ (32, 32, 9, 22, 1, 64) │              0 │ time_distributed_25[0… │
# │ (Concatenate)             │                        │                │ time_distributed_24[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_26       │ (32, 32, 9, 11, 1, 1)  │            513 │ SpaceConcat3[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceAttnCreate3          │ (32, 32, 9, 11, 276,   │              0 │ time_distributed_26[0… │
# │ (Multiply)                │ 64)                    │                │ TimeAttnCreate3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSpaceAttnApply3 (Add) │ (32, 32, 9, 11, 276,   │              0 │ SpaceAttnCreate3[0][0… │
# │                           │ 64)                    │                │ time_distributed_19[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_27       │ (32, 32, 9, 11, 276,   │            256 │ TimeSpaceAttnApply3[0… │
# │ (TimeDistributed)         │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_28       │ (32, 32, 9, 11, 276,   │         51,232 │ time_distributed_27[0… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_32       │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_28[0… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_31       │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_28[0… │
# │ (TimeDistributed)         │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_29       │ (32, 32, 1, 1, 276,    │          2,112 │ time_distributed_31[0… │
# │ (TimeDistributed)         │ 64)                    │                │ time_distributed_32[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_30       │ (32, 32, 1, 1, 276,    │          2,080 │ time_distributed_29[0… │
# │ (TimeDistributed)         │ 32)                    │                │ time_distributed_29[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAdd4 (Add)            │ (32, 32, 1, 1, 276,    │              0 │ time_distributed_30[1… │
# │                           │ 32)                    │                │ time_distributed_30[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSigmoid4 (Activation) │ (32, 32, 1, 1, 276,    │              0 │ TimeAdd4[0][0]         │
# │                           │ 32)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeAttnCreate4           │ (32, 32, 9, 11, 276,   │              0 │ TimeSigmoid4[0][0],    │
# │ (Multiply)                │ 32)                    │                │ time_distributed_28[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_34       │ (32, 32, 9, 11, 1, 32) │              0 │ TimeAttnCreate4[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_33       │ (32, 32, 9, 11, 1, 32) │              0 │ TimeAttnCreate4[0][0]  │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceConcat4              │ (32, 32, 9, 22, 1, 32) │              0 │ time_distributed_34[0… │
# │ (Concatenate)             │                        │                │ time_distributed_33[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_35       │ (32, 32, 9, 11, 1, 1)  │            257 │ SpaceConcat4[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ SpaceAttnCreate4          │ (32, 32, 9, 11, 276,   │              0 │ time_distributed_35[0… │
# │ (Multiply)                │ 32)                    │                │ TimeAttnCreate4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TimeSpaceAttnApply4 (Add) │ (32, 32, 9, 11, 276,   │              0 │ SpaceAttnCreate4[0][0… │
# │                           │ 32)                    │                │ time_distributed_28[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_36       │ (32, 32, 3, 3, 11, 32) │              0 │ TimeSpaceAttnApply4[0… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_37       │ (32, 32, 3168)         │              0 │ time_distributed_36[0… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_38       │ (32, 32, 64)           │        202,816 │ time_distributed_37[0… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_39       │ (32, 32, 32)           │          2,080 │ time_distributed_38[0… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_40       │ (32, 32, 64)           │          2,112 │ time_distributed_39[0… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_41       │ (32, 32, 1)            │             65 │ time_distributed_40[0… │
# │ (TimeDistributed)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ time_distributed_42       │ (32, 32, 1)            │              3 │ time_distributed_41[0… │
# │ (TimeDistributed)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 338,012 (1.29 MB)
#  Trainable params: 337,783 (1.29 MB)
#  Non-trainable params: 229 (920.00 B)

# %%
wordfreq_model.save('WordFreqModel.keras')

# %%
empty = np.zeros(276)
sent_end = np.random.rand(9,11,276)
sent_empty = np.zeros((9,11,276))
pad = np.zeros(1)
special_characters = '!@#$%^&*()_+-=[],."\''

train_x = []
train_y =[]

for s in np.unique(metadata['sent_ident']):
    sentence_meta = metadata[metadata['sent_ident']==s]
    sentence_eeg = epochs_df[epochs_df['epoch'].isin(sentence_meta.index)]
    sentence_x = []
    sentence_y = []
    length = len(np.unique(sentence_eeg['epoch']))

    if length<5 or length>30:
        #skip sentences that are too long or too short
        continue

    for w in np.unique(sentence_eeg['epoch']):
        temp = np.zeros(1)
        e = sentence_eeg[sentence_eeg['epoch']==w]
        meta = sentence_meta.loc[w]
        epoch_reshape = np.array([[empty,   empty,   empty,      empty,      e['Fp1'],  empty,   e['Fp2'],  empty,   empty,      empty,     empty],
                                [empty,   empty,   empty,      e['AF7'],   e['AF3'],  e['AFz'],e['AF4'],  e['AF8'],empty,      empty,     empty],
                                [empty,   e['F7'], e['F5'],    e['F3'],    e['F1'],   e['Fz'], e['F2'],   e['F4'], e['F6'],    e['F8'],   empty],
                                [e['FT9'],e['FT7'],e['FC5'],   e['FC3'],   e['FC1'],  e['FCz'],e['FC2'],  e['FC4'],e['FC6'],   e['FT8'],  e['FT10']],
                                [empty,   e['T7'], e['C5'],    e['C3'],    e['C1'],   e['Cz'], e['C2'],   e['C4'], e['C6'],    e['T8'],   empty],
                                [e['TP9'],e['TP7'],e['CP5'],   e['CP3'],   e['CP1'],  e['CPz'],e['CP2'],  e['CP4'],e['CP6'],   e['TP8'],  e['TP10']],
                                [empty,   e['P7'], e['P5'],    e['P3'],    e['P1'],   e['Pz'], e['P2'],   e['P4'], e['P6'],    e['P8'],   empty],
                                [empty,   empty,   empty,      e['PO7'],   e['PO3'],  e['POz'],e['PO4'],  e['PO8'],empty,      empty,     empty],
                                [empty,   empty,   empty,      empty,      e['O1'],   e['Oz'], e['O2'],   empty,   empty,      empty,     empty]])
        sentence_x.append(epoch_reshape)
        word_freq = meta['freq']
        temp[temp == 0] = word_freq
        emb = temp
        sentence_y.append(emb)

    sentence_x.append(sent_end)
    sentence_y.append(pad)
    for i in range(31-length):
        sentence_x.append(sent_empty)
        sentence_y.append(pad)

    train_x.append(sentence_x)
    train_y.append(sentence_y)

# %%
train_x = np.array(train_x)
train_y = np.array(train_y)

# %%
train_x.shape
# Out:
# (1236, 32, 9, 11, 276)

# %%
train_y.shape
# Out:
# (1236, 32, 1)

# %%
wordfreq_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.CosineSimilarity(),
    metrics=["accuracy"]
)

# %%
wordfreq_model.fit(
    x = train_x,
    y =  train_y,
    batch_size = 8,
    epochs = 10,
    validation_split = 0.125
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a6f13890995> in <cell line: 1>()
# ----> 1 wordfreq_model.fit(
#       2     x = train_x,
#       3     y =  train_y,
#       4     batch_size = 8,
#       5     epochs = 10,
#
# NameError: name 'wordfreq_model' is not defined
